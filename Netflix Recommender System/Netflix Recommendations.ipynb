# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df2 = df

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Creating a new sequential index column
df['id'] = range(1, len(df) + 1)

# %%
df['country'].value_counts()
# Out:
# country
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 748, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#id, title, director, cast, country, listedin, description, date
df = df[['id', 'title','director', 'cast', 'country', 'listed_in', 'description', 'date_added']]

# %%
df
# Out:
#         id                  title         director  \
# 0        1   Dick Johnson Is Dead  Kirsten Johnson
# 1        2          Blood & Water              NaN
# 2        3              Ganglands  Julien Leclercq
# 3        4  Jailbirds New Orleans              NaN
# 4        5           Kota Factory              NaN
# ...    ...                    ...              ...
# 8802  8803                 Zodiac    David Fincher
# 8803  8804            Zombie Dumb              NaN
# 8804  8805             Zombieland  Ruben Fleischer
# 8805  8806                   Zoom     Peter Hewitt
# 8806  8807                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
#Checking for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
df.fillna('', inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\1272664119.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna('', inplace=True)

# %% [markdown]
# ### Bar Chart of Content Types

# %%
# Count the occurrences of each content type
content_counts = df2['type'].value_counts()

plt.figure(figsize=(8, 6))
content_counts.plot(kind='bar', color=['blue', 'green'], alpha=0.7)
plt.title('Distribution of Content Types (Movies vs. TV Shows)')
plt.xlabel('Content Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Histogram of Release Years

# %%
plt.figure(figsize=(10, 6))
plt.hist(df2['release_year'], bins=30, edgecolor='black', alpha=0.7)
plt.title('Distribution of Release Years')
plt.xlabel('Release Year')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### WordCloud Of Genres

# %%
# !pip install wordcloud
# Out:
# ...
#    ---------------------------------------- 0.0/301.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.4 kB ? eta -:--:--
#    ---------------------------- ----------- 215.0/301.4 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 301.4/301.4 kB 3.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud

all_genres = ' '.join(df2['listed_in'])

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_genres)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Genres')
plt.show()

# %%
df['director'] = df['director'].apply(lambda x: x.replace(' ', '') if isinstance(x, str) else '')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\3197910105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['director'] = df['director'].apply(lambda x: x.replace(' ', '') if isinstance(x, str) else '')

# %%
df['cast'] = df['cast'].apply(lambda x: x.replace(' ', '') if isinstance(x, str) else '')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\2000737578.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cast'] = df['cast'].apply(lambda x: x.replace(' ', '') if isinstance(x, str) else '')

# %%
df['country'] = df['country'].apply(lambda x: x.replace(' ', '') if isinstance(x, str) else '')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\3951590489.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country'] = df['country'].apply(lambda x: x.replace(' ', '') if isinstance(x, str) else '')

# %%
df['date_added'] = df['date_added'].apply(lambda x: x.replace(' ', '') if isinstance(x, str) else '')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\3160124125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_added'] = df['date_added'].apply(lambda x: x.replace(' ', '') if isinstance(x, str) else '')

# %%
df['date_added'] = df['date_added'].apply(lambda x: x.replace(',', '') if isinstance(x, str) else '')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\284188232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_added'] = df['date_added'].apply(lambda x: x.replace(',', '') if isinstance(x, str) else '')

# %%
df.head()
# Out:
#    id                  title        director  \
# 0   1   Dick Johnson Is Dead  KirstenJohnson
# 1   2          Blood & Water
# 2   3              Ganglands  JulienLeclercq
# 3   4  Jailbirds New Orleans
# 4   5           Kota Factory
#
#                                                 cast       country  \
# 0                                                     UnitedStates
# 1  AmaQamata,KhosiNgema,GailMabalane,ThabangMolab...   SouthAfrica
# 2  SamiBouajila,TracyGotoas,SamuelJouy,NabihaAkka...
# 3
# 4  MayurMore,JitendraKumar,RanjanRaj,AlamKhan,Ahs...         India
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description       date_added
# ...

# %%
df['description'] = df['description'].apply(lambda x: x.split() if isinstance(x, str) else [])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\2762059558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['description'] = df['description'].apply(lambda x: x.split() if isinstance(x, str) else [])

# %%
df['country'] = df['country'].apply(lambda x: x.split() if isinstance(x, str) else [])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\2989407548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country'] = df['country'].apply(lambda x: x.split() if isinstance(x, str) else [])

# %%
df.head()
# Out:
#    id                  title        director  \
# 0   1   Dick Johnson Is Dead  KirstenJohnson
# 1   2          Blood & Water
# 2   3              Ganglands  JulienLeclercq
# 3   4  Jailbirds New Orleans
# 4   5           Kota Factory
#
#                                                 cast         country  \
# 0                                                     [UnitedStates]
# 1  AmaQamata,KhosiNgema,GailMabalane,ThabangMolab...   [SouthAfrica]
# 2  SamiBouajila,TracyGotoas,SamuelJouy,NabihaAkka...              []
# 3                                                                 []
# 4  MayurMore,JitendraKumar,RanjanRaj,AlamKhan,Ahs...         [India]
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# ...

# %%
df['director'] = df['director'].apply(lambda x: x.split())
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\2882913574.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['director'] = df['director'].apply(lambda x: x.split())

# %%
df['cast'] = df['cast'].apply(lambda x: x.split())
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\3269265924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cast'] = df['cast'].apply(lambda x: x.split())

# %%
df['listed_in'] = df['listed_in'].apply(lambda x: x.split())
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\2629833233.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['listed_in'] = df['listed_in'].apply(lambda x: x.split())

# %%
df['date_added'] = df['date_added'].apply(lambda x: x.split())
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\4105000693.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_added'] = df['date_added'].apply(lambda x: x.split())

# %%
df.head()
# Out:
#    id                  title          director  \
# 0   1   Dick Johnson Is Dead  [KirstenJohnson]
# 1   2          Blood & Water                []
# 2   3              Ganglands  [JulienLeclercq]
# 3   4  Jailbirds New Orleans                []
# 4   5           Kota Factory                []
#
#                                                 cast         country  \
# 0                                                 []  [UnitedStates]
# 1  [AmaQamata,KhosiNgema,GailMabalane,ThabangMola...   [SouthAfrica]
# 2  [SamiBouajila,TracyGotoas,SamuelJouy,NabihaAkk...              []
# 3                                                 []              []
# 4  [MayurMore,JitendraKumar,RanjanRaj,AlamKhan,Ah...         [India]
#
#                                            listed_in  \
# 0                                    [Documentaries]
# 1  [International, TV, Shows,, TV, Dramas,, TV, M...
# 2  [Crime, TV, Shows,, International, TV, Shows,,...
# ...

# %%
# Combine all the lists into a single 'tags' column
df['tags'] = ( 
    df['director'] + 
    df['cast'] + 
    df['country'] + 
    df['listed_in'] + 
    df['date_added'] + 
    df['description']
)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\316071304.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags'] = (

# %%
df.head()
# Out:
#    id                  title          director  \
# 0   1   Dick Johnson Is Dead  [KirstenJohnson]
# 1   2          Blood & Water                []
# 2   3              Ganglands  [JulienLeclercq]
# 3   4  Jailbirds New Orleans                []
# 4   5           Kota Factory                []
#
#                                                 cast         country  \
# 0                                                 []  [UnitedStates]
# 1  [AmaQamata,KhosiNgema,GailMabalane,ThabangMola...   [SouthAfrica]
# 2  [SamiBouajila,TracyGotoas,SamuelJouy,NabihaAkk...              []
# 3                                                 []              []
# 4  [MayurMore,JitendraKumar,RanjanRaj,AlamKhan,Ah...         [India]
#
#                                            listed_in  \
# 0                                    [Documentaries]
# 1  [International, TV, Shows,, TV, Dramas,, TV, M...
# 2  [Crime, TV, Shows,, International, TV, Shows,,...
# ...

# %%
new_df = df[['id', 'title', 'tags']]

# %%
new_df
# Out:
#         id                  title  \
# 0        1   Dick Johnson Is Dead
# 1        2          Blood & Water
# 2        3              Ganglands
# 3        4  Jailbirds New Orleans
# 4        5           Kota Factory
# ...    ...                    ...
# 8802  8803                 Zodiac
# 8803  8804            Zombie Dumb
# 8804  8805             Zombieland
# 8805  8806                   Zoom
# 8806  8807                 Zubaan
#
#                                                    tags
# 0     [KirstenJohnson, UnitedStates, Documentaries, ...
# 1     [AmaQamata,KhosiNgema,GailMabalane,ThabangMola...
# 2     [JulienLeclercq, SamiBouajila,TracyGotoas,Samu...
# 3     [Docuseries,, Reality, TV, September242021, Fe...
# 4     [MayurMore,JitendraKumar,RanjanRaj,AlamKhan,Ah...
# ...                                                 ...
# 8802  [DavidFincher, MarkRuffalo,JakeGyllenhaal,Robe...
# 8803  [Kids', TV,, Korean, TV, Shows,, TV, Comedies,...
# ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\3089450492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df.head()
# Out:
#    id                  title  \
# 0   1   Dick Johnson Is Dead
# 1   2          Blood & Water
# 2   3              Ganglands
# 3   4  Jailbirds New Orleans
# 4   5           Kota Factory
#
#                                                 tags
# 0  KirstenJohnson UnitedStates Documentaries Sept...
# 1  AmaQamata,KhosiNgema,GailMabalane,ThabangMolab...
# 2  JulienLeclercq SamiBouajila,TracyGotoas,Samuel...
# 3  Docuseries, Reality TV September242021 Feuds, ...
# 4  MayurMore,JitendraKumar,RanjanRaj,AlamKhan,Ahs...

# %%
new_df['tags'][0]
# Out:
# 'KirstenJohnson UnitedStates Documentaries September252021 As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.'

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\3214958533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

# %%
new_df.head()
# Out:
#    id                  title  \
# 0   1   Dick Johnson Is Dead
# 1   2          Blood & Water
# 2   3              Ganglands
# 3   4  Jailbirds New Orleans
# 4   5           Kota Factory
#
#                                                 tags
# 0  kirstenjohnson unitedstates documentaries sept...
# 1  amaqamata,khosingema,gailmabalane,thabangmolab...
# 2  julienleclercq samibouajila,tracygotoas,samuel...
# 3  docuseries, reality tv september242021 feuds, ...
# 4  mayurmore,jitendrakumar,ranjanraj,alamkhan,ahs...

# %%
new_df['tags'][0]
# Out:
# 'kirstenjohnson unitedstates documentaries september252021 as her father nears the end of his life, filmmaker kirsten johnson stages his death in inventive and comical ways to help them both face the inevitable.'

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=6000, stop_words='english')

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
feature_names = cv.get_feature_names_out()

# %%
feature_names
# Out:
# array(['000', '10', '100', ..., 'zoyaakhtar', 'álvarocervantes',
#        'ángelamolina'], dtype=object)

# %%
feature_names = list(cv.get_feature_names_out())
print(feature_names)
# Out:
# ['000', '10', '100', '11', '12', '13', '14', '15', '16', '17', '18', '18th', '1920', '1950', '1960', '1960s', '1970', '1970s', '1980', '1980s', '1989', '1990', '1990s', '1992', '1994', '1996', '19th', '20', '2011', '2012', '2014', '2015', '2016', '2018', '2020', '20th', '21st', '24', '25', '28', '30', '360º', '40', '50', '500', '50th', '60', '70', '80', '90', '90s', 'aamirbashir', 'aamirkhan', 'aaroneckhart', 'aaronpaul', 'aasifmandvi', 'abandon', 'abbytrott', 'abduct', 'abdullahal', 'abhaydeol', 'abhishekbachchan', 'abigailbreslin', 'abil', 'abl', 'aboard', 'abov', 'abroad', 'abruptli', 'absurd', 'abus', 'abuse', 'academ', 'academi', 'academy', 'accept', 'access', 'accid', 'accident', 'acclaim', 'accompani', 'account', 'accus', 'achiev', 'acquir', 'act', 'action', 'activ', 'activist', 'actor', 'actress', 'actual', 'ad', 'adam', 'adampally', 'adamsandler', 'adamscott', 'adapt', 'add', 'addict', 'addiction', 'ademolaadedoyin', 'adesuaetomi', 'adilhussain', 'adipatidolken', 'aditiraohy
# ...

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []

    for i in text.split():
        y.append(ps.stem(i))

    return " ".join(y)

# %%
ps.stem('loving')
# Out:
# 'love'

# %%
new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8832\3213734980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=4000, stop_words='english')

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
feature_names = list(cv.get_feature_names_out())
print(feature_names)
# Out:
# ['000', '10', '100', '11', '12', '13', '14', '15', '16', '17', '18', '18th', '1950', '1960', '1960s', '1970', '1970s', '1980', '1980s', '1990', '1992', '1994', '19th', '20', '2012', '2015', '2018', '20th', '24', '25', '30', '40', '50', '500', '60', '70', '80', 'aamirkhan', 'aaronpaul', 'abandon', 'abduct', 'abhaydeol', 'abhishekbachchan', 'abil', 'aboard', 'abov', 'abroad', 'absurd', 'abu', 'academ', 'academi', 'academy', 'accept', 'access', 'accid', 'accident', 'acclaim', 'accompani', 'account', 'accu', 'achiev', 'acquir', 'act', 'action', 'activ', 'activist', 'actor', 'actress', 'actual', 'ad', 'adam', 'adampally', 'adamsandler', 'adamscott', 'adapt', 'add', 'addict', 'adesuaetomi', 'adilhussain', 'aditiraohydari', 'adjust', 'adopt', 'ador', 'adult', 'adulthood', 'adventur', 'adventure', 'adventures', 'advoc', 'affair', 'affect', 'affluent', 'afghanistan', 'afloat', 'africa', 'african', 'aftermath', 'ag', 'age', 'agenc', 'agenda', 'agent', 'ago', 'agr', 'ah', 'ahead', 'ahmedhelmy',
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
cosine_similarity(vectors).shape
# Out:
# (8807, 8807)

# %%
similarity
# Out:
# array([[1.        , 0.        , 0.15294382, ..., 0.05564149, 0.11128298,
#         0.31022669],
#        [0.        , 1.        , 0.40946151, ..., 0.        , 0.        ,
#         0.06388766],
#        [0.15294382, 0.40946151, 1.        , ..., 0.0404226 , 0.0404226 ,
#         0.19720266],
#        ...,
#        [0.05564149, 0.        , 0.0404226 , ..., 1.        , 0.05882353,
#         0.        ],
#        [0.11128298, 0.        , 0.0404226 , ..., 0.05882353, 1.        ,
#         0.040996  ],
#        [0.31022669, 0.06388766, 0.19720266, ..., 0.        , 0.040996  ,
#         1.        ]])

# %%
sorted(list(enumerate(similarity[0])), reverse=True, key=lambda x:x[1])[1:6]
# Out:
# [(6133, 0.44513190725972573),
#  (8691, 0.43052838591144593),
#  (2988, 0.4214636152117623),
#  (6038, 0.4210526315789473),
#  (6327, 0.4210526315789473)]

# %%
def recommend(movie):
    movie_index = new_df[new_df['title'].str.lower() == movie.lower()].index
    if len(movie_index) == 0:
        print("Movie not found.")
        return
    movie_index = movie_index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:6]

    for i in movies_list:
        print(new_df.iloc[i[0]].title)

# %%
recommend('Kota Factory')
# Out:
# Little Things
# College Romance
# O-Negative, Love Can’t Be Designed
# Bhaage Re Mann
# Bhaag Beanie Bhaag

# %%
recommend('Peaky Blinders')
# Out:
# The Fear
# My Hotter Half
# The Irregulars
# Criminal: UK
# Vexed

# %%
recommend('Superbad')
# Out:
# Can't Hardly Wait
# The Last Summer
# The Kissing Booth
# F the Prom
# Freak Show

# %%
recommend('Sacred Games')
# Out:
# Khotey Sikkey
# Delhi Crime
# She
# Babylon Berlin
# Şubat
